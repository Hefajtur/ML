# %% [markdown]
# <a href="https://colab.research.google.com/github/Hefajtur/ML/blob/main/svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_csv('/content/drive/MyDrive/csv/credit card taiwan svm algorithm.csv')

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1  24.0      2      2     -1
# 1          2   120000.0    2          2         2  26.0     -1      2      0
# 2          3    90000.0    2          2         2   NaN      0      0      0
# 3          4    50000.0    2          2         1   NaN      0      0      0
# 4          5    50000.0    1          2         1  57.0     -1      0     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.0      0      0      0
# 29996  29997   150000.0    1          3         2  43.0     -1     -1     -1
# 29997  29998    30000.0    1          2         2  37.0      4      3      2
# 29998  29999    80000.0    1          3         1  41.0      1     -1      0
# 29999  30000    50000.0    1          2         1  46.0      0      0      0
#
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           2
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
miss = df.AGE.mean()

# %%
df.AGE = df.AGE.fillna(miss)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  \
# 0          1    20000.0    2          2         1  24.000000      2      2
# 1          2   120000.0    2          2         2  26.000000     -1      2
# 2          3    90000.0    2          2         2  35.485499      0      0
# 3          4    50000.0    2          2         1  35.485499      0      0
# 4          5    50000.0    1          2         1  57.000000     -1      0
# ...      ...        ...  ...        ...       ...        ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.000000      0      0
# 29996  29997   150000.0    1          3         2  43.000000     -1     -1
# 29997  29998    30000.0    1          2         2  37.000000      4      3
# 29998  29999    80000.0    1          3         1  41.000000      1     -1
# 29999  30000    50000.0    1          2         1  46.000000      0      0
#
# ...

# %%
x = df.drop(['default.payment.next.month'],axis=1)
x
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE        AGE  PAY_0  PAY_2  \
# 0          1    20000.0    2          2         1  24.000000      2      2
# 1          2   120000.0    2          2         2  26.000000     -1      2
# 2          3    90000.0    2          2         2  35.485499      0      0
# 3          4    50000.0    2          2         1  35.485499      0      0
# 4          5    50000.0    1          2         1  57.000000     -1      0
# ...      ...        ...  ...        ...       ...        ...    ...    ...
# 29995  29996   220000.0    1          3         1  39.000000      0      0
# 29996  29997   150000.0    1          3         2  43.000000     -1     -1
# 29997  29998    30000.0    1          2         2  37.000000      4      3
# 29998  29999    80000.0    1          3         1  41.000000      1     -1
# 29999  30000    50000.0    1          2         1  46.000000      0      0
#
# ...

# %%
y = df['default.payment.next.month']
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 29995    0
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: default.payment.next.month, Length: 30000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)
xtrain
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  \
# 10009  10010    30000.0    2          1         2  23.0      0      0      0
# 23909  23910    80000.0    1          2         1  26.0     -1      3      2
# 7209    7210   230000.0    2          5         2  23.0      0      0      0
# 22005  22006   110000.0    2          1         2  27.0      0      0      0
# 6674    6675   240000.0    1          1         2  34.0     -1     -1     -1
# ...      ...        ...  ...        ...       ...   ...    ...    ...    ...
# 7092    7093   220000.0    2          2         2  41.0      0      0      0
# 17920  17921    50000.0    1          2         2  25.0      0      0      0
# 18980  18981    80000.0    2          2         2  32.0     -2     -2     -2
# 13139  13140   200000.0    2          2         1  50.0     -1     -1     -2
# 1942    1943   120000.0    1          1         1  45.0      0      0      0
#
# ...

# %%
model = SVC()

# %%
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model.score(xtest,ytest)
# Out:
# 0.7788333333333334

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier()
clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
clf.score(xtest,ytest)
# Out:
# 0.8165

# %%
from sklearn.tree import DecisionTreeClassifier
dc = DecisionTreeClassifier()

# %%
dc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dc.score(xtest,ytest)
# Out:
# 0.7315
